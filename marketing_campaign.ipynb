# %% [markdown]
# <a href="https://colab.research.google.com/github/zakari90/-DataAnalysis/blob/main/marketing_campaign.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
path= "/content/drive/MyDrive/hsoub ai/marketing_campaign_data/nyt1.csv"
df = pd.read_csv(path)
df.shape
# Out:
# (458441, 5)

# %%
df.head()
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In
# 0   36       0            3       0          1
# 1   73       1            3       0          1
# 2   30       0            3       0          1
# 3   49       1            3       0          1
# 4   47       1           11       0          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458441 entries, 0 to 458440
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Age          458441 non-null  int64
#  1   Gender       458441 non-null  int64
#  2   Impressions  458441 non-null  int64
#  3   Clicks       458441 non-null  int64
#  4   Signed_In    458441 non-null  int64
# dtypes: int64(5)
# memory usage: 17.5 MB

# %%
df.columns = [col.lower() for col in df]
df
# Out:
#         age  gender  impressions  clicks  signed_in age_group
# 0        36       0            3       0          1     35-44
# 1        73       1            3       0          1       65+
# 2        30       0            3       0          1     25-34
# 3        49       1            3       0          1     45-54
# 4        47       1           11       0          1     45-54
# ...     ...     ...          ...     ...        ...       ...
# 458436    0       0            2       0          0       <18
# 458437    0       0            4       0          0       <18
# 458438   72       1            5       0          1       65+
# 458439    0       0            5       0          0       <18
# 458440    0       0            3       0          0       <18
#
# [458441 rows x 6 columns]

# %%
df.describe()
# Out:
#                  age         gender    impressions         clicks  \
# count  458441.000000  458441.000000  458441.000000  458441.000000
# mean       29.482551       0.367037       5.007316       0.092594
# std        23.607034       0.481997       2.239349       0.309973
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       3.000000       0.000000
# 50%        31.000000       0.000000       5.000000       0.000000
# 75%        48.000000       1.000000       6.000000       0.000000
# max       108.000000       1.000000      20.000000       4.000000
#
#            signed_in
# count  458441.000000
# mean        0.700930
# std         0.457851
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
bins = [0, 18, 25, 35, 45, 55, 65, 110]
labels = ['<18', '18-24', '25-34', '35-44', '45-54', '55-64', '65+']
df['age_group'] = pd.cut(df.age, bins = bins, labels = labels, include_lowest = True)
df
# Out:
#         age  gender  impressions  clicks  signed_in age_group
# 0        36       0            3       0          1     35-44
# 1        73       1            3       0          1       65+
# 2        30       0            3       0          1     25-34
# 3        49       1            3       0          1     45-54
# 4        47       1           11       0          1     45-54
# ...     ...     ...          ...     ...        ...       ...
# 458436    0       0            2       0          0       <18
# 458437    0       0            4       0          0       <18
# 458438   72       1            5       0          1       65+
# 458439    0       0            5       0          0       <18
# 458440    0       0            3       0          0       <18
#
# [458441 rows x 6 columns]

# %%
sns.countplot(x='age_group', hue='gender', data=df)
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
df.head()
# Out:
#    age  gender  impressions  clicks  signed_in age_group
# 0   36       0            3       0          1     35-44
# 1   73       1            3       0          1       65+
# 2   30       0            3       0          1     25-34
# 3   49       1            3       0          1     45-54
# 4   47       1           11       0          1     45-54

# %%
sns.countplot(x='clicks', hue='age_group', data=df)
# Out:
# <Axes: xlabel='clicks', ylabel='count'>

# %%
df[(df['clicks']>0) & (df['impressions']==0)]
# Out:
# Empty DataFrame
# Columns: [age, gender, impressions, clicks, signed_in, age_group]
# Index: []

# %%
sns.histplot(df, x='impressions', hue='age_group', stat='count', binwidth=1, multiple='stack')
# Out:
# <Axes: xlabel='impressions', ylabel='Count'>

# %%
sns.boxplot(y=df['impressions'], x=df['age_group'])
# Out:
# <Axes: xlabel='age_group', ylabel='impressions'>

# %%
df['CTR'] = round(df['clicks']/df['impressions'], 5)

# %%
sns.boxenplot(x=df['age_group'], y = df['CTR'])
# Out:
# <Axes: xlabel='age_group', ylabel='CTR'>

# %%
bins = [-1, 0, 0.1, 0.2, 0.4, 1]
labels = ['0', '<10%', '10%-20%', '20%-40%', '>40%']
df['CTR_group'] = pd.cut(df.CTR, bins, labels = labels)
df.CTR_group.value_counts(normalize=True, sort=True)
# Out:
# CTR_group
# 0          0.912516
# 10%-20%    0.054654
# 20%-40%    0.023328
# <10%       0.004996
# >40%       0.004506
# Name: proportion, dtype: float64

# %%
df_Clicked = df[df['CTR'] > 0]
df_Clicked.head()
# Out:
#     age  gender  impressions  clicks  signed_in age_group      CTR CTR_group
# 5    47       0           11       1          1     45-54  0.09091      <10%
# 6     0       0            7       1          0       <18  0.14286   10%-20%
# 10    0       0            8       1          0       <18  0.12500   10%-20%
# 39    0       0            7       2          0       <18  0.28571   20%-40%
# 63    0       0            2       1          0       <18  0.50000      >40%

# %%
df_Clicked.shape
# Out:
# (39838, 8)

# %%
df_Clicked.age_group.value_counts(normalize=True)
# Out:
# age_group
# <18      0.505723
# 55-64    0.106757
# 65+      0.099152
# 35-44    0.090190
# 45-54    0.079397
# 25-34    0.073297
# 18-24    0.045484
# Name: proportion, dtype: float64

# %%
sns.boxenplot(x = df_Clicked['age_group'], y = df_Clicked['CTR'])
# Out:
# <Axes: xlabel='age_group', ylabel='CTR'>

# %%
sns.countplot(x='age_group', hue='gender', data=df_Clicked)
# Out:
# <Axes: xlabel='age_group', ylabel='count'>

# %%
sns.countplot(x='age_group', hue='signed_in', data=df_Clicked)
# Out:
# <Axes: xlabel='age_group', ylabel='count'>
